# %%
import pandas as pd
from pycaret.datasets import get_data
from pycaret.classification import *

data = pd.read_csv('C:/Users/ekyfe/Documents/college/Semester 4/MLOps/praktikum/streamlit/obesity_data1.csv')
data.fillna(data.mean(), inplace=True)
s = setup(data, target='NObeyesdad', session_id=123)
best = compare_models()
model = tune_model(best)
evaluate_model(model)
finalize_model(model)
save_model(model, 'obesity_pipeline')
# Out:
# <style type="text/css">
# #T_fb35a_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fb35a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb35a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_fb35a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb35a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fb35a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_fb35a_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_fb35a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fb35a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_fb35a_row1_col1" class="data row1 col1" >NObeyesdad</td>
#     </tr>
#     <tr>
#       <th id="T_fb35a_level0_row2" class="row_heading level0 row2" >2</th>
# ...
